# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
base=1000000
st=16000
put=200
ex=np.arange(st,20100,100)
leverage=(ex*put)/((ex-st)*put+base)
s=pd.Series(leverage,index=ex)
s.plot()
# Out:
# <Axes: >
